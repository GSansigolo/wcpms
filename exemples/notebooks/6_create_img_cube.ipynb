# %%
from cshd import cshd_img_cube
import os

# %%
path_dir = os.path.abspath("")

S2_NDVI_cube = cshd_img_cube(
    data_dir=os.path.join(path_dir,'021037/')
)

# %%
S2_NDVI_cube
# Out:
# <xarray.Dataset> Size: 10GB
# Dimensions:      (band: 1, x: 10560, y: 10560, time: 22)
# Coordinates:
#   * band         (band) int64 8B 1
#   * x            (x) float64 84kB 5.264e+06 5.264e+06 ... 5.37e+06 5.37e+06
#   * y            (y) float64 84kB 7.941e+06 7.941e+06 ... 7.835e+06 7.835e+06
#     spatial_ref  int64 8B 0
#   * time         (time) datetime64[ns] 176B 2023-01-01 2023-01-17 ... 2023-12-19
# Data variables:
#     band_data    (time, band, y, x) float32 10GB -6.864e+03 ... -230.0

# %%
import matplotlib.pyplot as plt

# %%
S2_NDVI_cube_2d = S2_NDVI_cube['band_data'].sel(time='2023-01-01')

S2_NDVI_cube_2d.plot()
