# %%
from cshd import cshd_img_cube, params_phenometrics, calc_phenometrics
import os

# %%
path_dir = os.path.abspath("")

ndvi_data_cube = cshd_img_cube(
    data_dir=os.path.join(path_dir,'images/')
)

# %%
ndvi_data_cube
# Out:
# <xarray.Dataset> Size: 10GB
# Dimensions:      (band: 1, x: 10560, y: 10560, time: 23)
# Coordinates:
#   * band         (band) int64 8B 1
#   * x            (x) float64 84kB 5.792e+06 5.792e+06 ... 5.898e+06 5.898e+06
#   * y            (y) float64 84kB 9.947e+06 9.947e+06 ... 9.842e+06 9.842e+06
#     spatial_ref  int64 8B 0
#   * time         (time) datetime64[ns] 184B 2021-01-01 2021-01-17 ... 2021-12-19
# Data variables:
#     band_data    (time, band, y, x) float32 10GB 6.142e+03 ... 5.921e+03

# %%
import matplotlib.pyplot as plt

# %%
ndvi_data_cube_2d = ndvi_data_cube['band_data'].sel(time='2021-01-01')

ndvi_data_cube_2d.plot()
